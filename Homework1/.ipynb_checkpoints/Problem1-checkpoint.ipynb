# %%
import matplotlib.pyplot as plt
import numpy as np
import math

mu = 0
variance = 25
sigma = math.sqrt(variance) 
xarr = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(xarr,[1/(sigma*math.sqrt(2* math.pi))*math.exp((-1/2)*(x/sigma)**2) for x in xarr])
plt.show()
